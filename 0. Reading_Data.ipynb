# %%
import pandas as pd
import numpy as np

# %%
# ss1 stands for satisfaction score which is first table.
pd.set_option("display.max_columns", None)
ss1=pd.read_csv("Survey data_Inflight Satisfaction Score.csv")
ss1
# Out:
#        flight_number origin_station_code destination_station_code  \
# 0               3802                 MKX                      ORX
# 1               4645                 COX                      DEX
# 2               5236                 COX                      DEX
# 3               4686                 DEX                      COX
# 4                671                 DEX                      COX
# ...              ...                 ...                      ...
# 47069              2                 SFX                      SIX
# 47070              2                 SFX                      SIX
# 47071              3                 SIX                      SFX
# 47072              3                 SIX                      SFX
# 47073              2                 SFX                      SIX
#
#       record_locator scheduled_departure_date  \
# 0             CYXXJJ                 9/1/2022
# 1             DRXXMH                 9/1/2022
# ...

# %%
# cf2 stands for Customer comments/feedback which is second table.
cf2=pd.read_csv("Survey data _Customer comments.csv")
cf2
# Out:
#       flight_number origin_station_code destination_station_code  \
# 0               950                 LHX                      SFX
# 1               950                 LHX                      SFX
# 2              1876                 FLX                      EWX
# 3              5469                 SFX                      SEX
# 4               281                 DEX                      ANX
# ...             ...                 ...                      ...
# 9419           2175                 YYX                      ORX
# 9420            680                 DEX                      GRX
# 9421           1420                 CLX                      FLX
# 9422           4746                 LAX                      EUX
# 9423           3773                 IAX                      YOX
#
#      scheduled_departure_date arrival_delay_group departure_delay_group  \
# 0                  2022-09-01      Early & Ontime               Delayed
# ...

# %%
# id3 stands for Inflight Service: Inventory data which is third table.
id3=pd.read_csv("Inflight Service_Inventory data.csv")
id3
# Out:
#        flight_number departure_station_code arrival_station_code  \
# 0               2634                    IAX                  PDX
# 1               2666                    ORX                  IAX
# 2               2310                    DEX                  SAX
# 3               1712                    SFX                  CLX
# 4               1225                    LAX                  HNX
# ...              ...                    ...                  ...
# 61262            711                    ORX                  AUX
# 61263           1914                    IAX                  LAX
# 61264           1417                    IAX                  LAX
# 61265           1005                    LAX                  ITX
# 61266            583                    YYX                  SFX
#
#       scheduled_departure_dtl  entree_product_id  \
# 0                    9/1/2022              58019
# 1                    9/1/2022              60549
# ...

# %%
# pd4 stands for Inflight Service: Pre order data which is fourth table.
pd4=pd.read_csv("Inflight Service_Pre order data.csv")
pd4
# Out:
#         flight_number departure_station_code arrival_station_code  \
# 0                1423                    INX                  DEX
# 1                1620                    IAX                  CUX
# 2                1852                    ORX                  PDX
# 3                 548                    IAX                  SFX
# 4                1155                    IAX                  CUX
# ...               ...                    ...                  ...
# 212034           2189                    DEX                  FLX
# 212035           1618                    LAX                  ORX
# 212036           1498                    SFX                  IAX
# 212037           1830                    EWX                  SFX
# 212038           2237                    ORX                  DEX
#
#        record_locator carrier_code scheduled_departure_dtl cabin_code  \
# 0              B3XX1H           UA                9/1/2022          J
# ...

# %%
ss1['score'].value_counts()
# Out:
# 2                         8250
# 1                         7713
# 5                         6733
# 3                         6390
# 4                         5877
# chicken entrée            4936
# other (specify)           2982
# vegetarian entrée         2010
# beef entrée                896
# sandwich/burger/wrap       666
# seafood entrée             403
# snack basket selection     218
# Name: score, dtype: int64

# %%
pd4['meal_group'].value_counts()
# Out:
# ENTREES HOT                   147826
# UNITED CATERER OWNED 88-3F     33094
# LIQUOR                          4167
# ALCOHOL BEVERAGES               2680
# BEER                            2120
# ENTREES COLD                    1796
# SANDWICHES                        45
# Name: meal_group, dtype: int64
